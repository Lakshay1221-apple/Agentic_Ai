# %% [markdown]
# ## Messages
# Role  -> Identifies the message type ;
#
# Content -> Represents the actual content of the message ;
#
# Metadata -> Optional such as response information , messages , ids, and token usages

# %%
import os 
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model
load_dotenv()

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

model = init_chat_model("groq:llama-3.3-70b-versatile")
model.invoke("Hello, how are you?")
# Out:
# AIMessage(content="Hello. I'm just a language model, so I don't have feelings or emotions like humans do, but I'm functioning properly and ready to assist you with any questions or topics you'd like to discuss. How about you? How's your day going so far?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 55, 'prompt_tokens': 41, 'total_tokens': 96, 'completion_time': 0.113551255, 'completion_tokens_details': None, 'prompt_time': 0.002210552, 'prompt_tokens_details': None, 'queue_time': 0.057651193, 'total_time': 0.115761807}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019f9d68-45b0-7a82-b5d3-600faa9300ac-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 41, 'output_tokens': 55, 'total_tokens': 96})

# %% [markdown]
# ### Text Prompt

# %%
model.invoke("What is the weather like today?")
# Out:
# AIMessage(content="I'm a large language model, I don't have have access to real-time weather information. I can suggest some ways for you to find out the current weather:\n\n1. **Check online weather websites**: You can visit websites like weather.com, accuweather.com, or wunderground.com to get the current weather conditions and forecast for your location.\n2. **Use a mobile app**: Download a weather app on your smartphone, such as Dark Sky, Weather Underground, or The Weather Channel, to get current weather conditions and forecasts.\n3. **Check your local news**: Watch your local news or check their website for weather updates.\n4. **Look out the window**: If you're at home or near a window, you can simply look outside to see the current weather conditions!\n\nPlease let me know if you have any other questions or if there's anything else I can help you with.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 181, 'prompt_tokens': 42, 'total_tokens': 223
# ...

# %% [markdown]
# ### Message Prompts

# %%
from langchain.messages import SystemMessage, HumanMessage, AIMessage

messages = [
    SystemMessage(content="You are a backend expert."),
    HumanMessage(content="Can you help me ? "),
    AIMessage(content="Hello! How can I assist you today?"),
    HumanMessage(content="Can you explain me about crud operations ?"),
]

response = model.invoke(messages) 
response
# Out:
# AIMessage(content='CRUD operations are the basic functions that allow you to interact with a database or a data storage system. CRUD stands for:\n\n1. **C** - Create: This operation allows you to add new data to the database. For example, if you\'re building a user management system, the create operation would allow you to add a new user to the database.\n2. **R** - Read (or Retrieve): This operation allows you to fetch or retrieve existing data from the database. Using the same user management system example, the read operation would allow you to retrieve a list of all users or a specific user\'s details.\n3. **U** - Update: This operation allows you to modify or update existing data in the database. For instance, if a user\'s email address changes, the update operation would allow you to modify the user\'s email address in the database.\n4. **D** - Delete: This operation allows you to remove or delete existing data from the database. If a user is no longer needed, the delete operat
# ...

# %%
response.usage_metadata
# Out:
# {'input_tokens': 74, 'output_tokens': 469, 'total_tokens': 543}
