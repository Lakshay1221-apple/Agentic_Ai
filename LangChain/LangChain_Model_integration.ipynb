# %% [markdown]
# ## Model Integration with GEMINI and GROQ

# %%
import os
from dotenv import load_dotenv 
load_dotenv()

os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %%
import os
from langchain.chat_models import init_chat_model

gemini = init_chat_model(
    model="google_genai:gemini-2.5-flash",
    temperature=0.7,
    api_key=os.getenv("GOOGLE_API_KEY"),
    model_kwargs={
        "max_output_tokens": 1024,
        "top_p": 0.95,
        "top_k": 40,
    },
)

groq = init_chat_model(
    model="groq:llama-3.3-70b-versatile",
    temperature=0.1,
    max_tokens=1024,          
    top_p=0.95,               
    api_key=os.getenv("GROQ_API_KEY"),
)

gemini, groq

# %%
gemini.invoke("Hello, how are you?")

# %%
groq.invoke("Hello, how are you?")

# %% [markdown]
# ## Streaming and Batch

# %%
gemini.stream("Write a 200 words paragraph about the benefits of using LangChain for building AI applications.")
